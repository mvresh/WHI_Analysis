# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ae585be6-ba37-4307-8077-c4c41ead7184" name="files[]" multiple disabled />
#      <output id="result-ae585be6-ba37-4307-8077-c4c41ead7184">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
data = pd.read_csv('World_Happiness_2015_2017.csv')

# We then use data.head() to see the first 5 rows of data
data.head()
# Out:
#        Country  Happiness Rank  ...  Dystopia Residual  Year
# 0  Switzerland               1  ...            2.51738  2015
# 1      Iceland               2  ...            2.70201  2015
# 2      Denmark               3  ...            2.49204  2015
# 3       Norway               4  ...            2.46531  2015
# 4       Canada               5  ...            2.45176  2015
#
# [5 rows x 11 columns]

# %%
data.shape
# Out:
# (470, 11)

# %%
data.dtypes
# Out:
# Country                           object
# Happiness Rank                     int64
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Year                               int64
# dtype: object

# %%
data['Year'] = data['Year'].astype('float')
data.dtypes
data.head()
data['Year'] = data['Year'].astype('int')
data.isnull().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# Year                             0
# dtype: int64

# %%
g = sns.pairplot(data)
g.fig.suptitle('FacetGrid plot', fontsize = 20)
g.fig.subplots_adjust(top= 0.95);

# %%
econ_happiness = ['Happiness Score','Economy (GDP per Capita)']
econ_corr = data[econ_happiness]
econ_corr.corr()
# Out:
#                           Happiness Score  Economy (GDP per Capita)
# Happiness Score                   1.00000                   0.78545
# Economy (GDP per Capita)          0.78545                   1.00000

# %%
sns.regplot(data = econ_corr, x = 'Economy (GDP per Capita)', y = 'Happiness Score').set_title("Correlation graph for Happiness score vs Economy")
# Out:
# Text(0.5, 1.0, 'Correlation graph for Happiness score vs Economy')

# %%
attributes = ['Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual']

# %%
attributes_corr = data[attributes]

attributes_corr.corr()
# Out:
#                                  Family  ...  Dystopia Residual
# Family                         1.000000  ...          -0.081537
# Health (Life Expectancy)       0.486383  ...           0.057674
# Freedom                        0.425377  ...           0.038422
# Trust (Government Corruption)  0.289768  ...          -0.162386
# Generosity                    -0.083528  ...           0.047765
# Dystopia Residual             -0.081537  ...           1.000000
#
# [6 rows x 6 columns]

# %%
df_corr = attributes_corr.corr()
df_corr

# %%
df_corr2 = df_corr
df_corr2[attributes] = pow(df_corr2[attributes],2)
df_corr2
